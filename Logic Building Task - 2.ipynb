# %% [markdown]
# <a href="https://colab.research.google.com/github/mu-janane-27/Innomatics-Research-lab-tasks/blob/main/Logic%20Building%20Task%20-%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unique Words in a Sentence

# %%
sentence = input("Enter sentence: ")
words = sentence.split()
unique_words = set()
for word in words:
    unique_words.add(word)
print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence: python is easy and python is powerfu
# Unique words count: 5
# Unique words: {'easy', 'powerfu', 'python', 'is', 'and'}

# %% [markdown]
# Highest Salary from Employee Data

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}
# Assumeing the salary of the first emloyee is the highest
highest_employee = ""
highest_salary = 0

# Loop through dictionary
for name in employees:
    salary = employees[name]

    if salary > highest_salary:
        highest_salary = salary
        highest_employee = name

# Print result
print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# Find Maximum and Minimum Values

# %%
numbers = [45, 22, 89, 10, 66]
maximum = numbers[0]
minimum = numbers[0]
for num in numbers:
    if num > maximum:
        maximum = num

    if num < minimum:
        minimum = num

print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# Count Products Above a Price Threshold

# %%
prices = [450, 1200, 899, 1500, 300]
count = 0
for price in prices:
    if price > 1000:
        count = count + 1
print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %% [markdown]
# Calculate Attendance Percentage

# %%
attendance = ["P", "P", "A", "P", "P"]
present_count = 0
for day in attendance:
    if day == "P":
        present_count += 1
total_days = len(attendance)
percentage = (present_count / total_days) * 100
print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# Remove Duplicate Phone Numbers

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]
unique_numbers = set()
for number in phone_numbers:
    unique_numbers.add(number)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# Count Character Frequency

# %%
text = "python"
frequency = {}
for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1
print(frequency)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# Convert List to Tuple

# %%
numbers = [10, 20, 30]
print("Original List:", numbers)
converted_tuple = tuple(numbers)
print("Converted Tuple:", converted_tuple)
# Out:
# Original List: [10, 20, 30]
# Converted Tuple: (10, 20, 30)

# %% [markdown]
# Check if a Key Exists in a Dictionary

# %%
employees = {
    "sajith": 50000,
    "janane": 60000,
    "aditi": 55000,
    "suprajaa": 62000
}
name = "janane"
if name in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# Calculate Average Marks

# %%
marks = [70, 80, 65, 75]
total = 0
for mark in marks:
    total = total + mark
count = len(marks)
average = total / count
print("Average Marks:", average)
# Out:
# Average Marks: 72.5
