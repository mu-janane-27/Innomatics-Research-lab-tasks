# %% [markdown]
# <a href="https://colab.research.google.com/github/mu-janane-27/Innomatics-Research-lab-tasks/blob/main/Logic%20Building%20Task%20%E2%80%93%201%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. User Login Check

# %%
proper_username = "admin"
proper_password = "1234"
username = input("Enter username: ")
password = input("Enter password: ")
if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %% [markdown]
# 2. Pass / Fail Analyzer

# %%
marks = [45, 78, 90, 33, 60]
pass_students = 0
fail_students = 0
for i in range(len(marks)):
    if marks[i] >= 50:
        pass_students += 1
    else:
        fail_students += 1
print("Total Number Of Pass Students:", pass_students)
print("Total Number Of Fail Students:", fail_students)
# Out:
# Total Number Of Pass Students: 3
# Total Number Of Fail Students: 2

# %% [markdown]
# 3. Simple Data Cleaner

# %%
names = [" Alice ", "bob", " CHARLIE "]
for name in names:
    name = name.strip()
    name = name.lower()
    print(name)
# Out:
# alice
# bob
# charlie

# %% [markdown]
# 4. Message Length Analyzer

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for message in messages:
    length = len(message)
    print("Message:", message)
    print("Length:", length)
    print(" ")
    if length > 10:
        print("This message is longer than 10 characters")
        print(" ")
# Out:
# Message: Hi
# Length: 2
#
# Message: Welcome to the platform
# Length: 23
#
# This message is longer than 10 characters
#
# Message: OK
# Length: 2

# %% [markdown]
# 5. Error Message Detector

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error_number = 0
for log in logs:
    if log == "ERROR":
        error_number = error_number + 1
print("Total ERROR entries:", error_number)
# Out:
# Total ERROR entries: 2
